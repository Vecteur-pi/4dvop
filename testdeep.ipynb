# %% [markdown]
# <a href="https://colab.research.google.com/github/Vecteur-pi/4dvop/blob/master/testdeep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#scikit learn: librairie de machine learning
from sklearn import datasets
from sklearn import model_selection

#keras: librairie de deep learning
from keras import models
from keras import layers

#numpy: utilitaire de calculs
import numpy as np

#matplotlib: librairie graphique
import matplotlib.pyplot as plt

# %% [markdown]
# chargement des lib necessaire

# %%
x,y = datasets.make_moons(n_samples=1500, shuffle =True, noise = 0.3)

# %%
print (y[0:5])
# Out:
# [1 0 0 0 0]

# %%
plt.figure()
plt.scatter(x[: , 0], x[: , 1], c=y)
